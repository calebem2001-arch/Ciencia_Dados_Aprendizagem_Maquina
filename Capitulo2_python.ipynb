# %% [markdown]
# <a href="https://colab.research.google.com/github/calebem2001-arch/Ciencia_Dados_Aprendizagem_Maquina/blob/main/Capitulo2_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
** Calebe Mendes | UDF | Sistemas de Informações **

- Dados Tabulares com Pandas - Funções Básicas

- Tipos de Dados com Pandas

- Renomeando Colunas acionando Listas e Colunas

- Adicionando e Removendo Colunas

- Operações Básicas - Consultas

- Operações Básicas - Filtro

- Operações Básicas - Combinando DataFrames

- Operações Básicas - Salvando DataFrames

# %% [markdown]
# ** Calebe Mendes | UDF | Sistemas de Informações **
#
# - Dados Tabulares com Pandas - Funções Básicas
#
# - Tipos de Dados com Pandas
#
# - Renomeando Colunas acionando Listas e Colunas
#
# - Adicionando e Removendo Colunas
#
# - Operações Básicas - Consultas
#
# - Operações Básicas - Filtro
#
# - Operações Básicas - Combinando DataFrames
#
# - Operações Básicas - Salvando DataFrames

# %%
cidades = pd.DataFrame(
    [
        ['Paraná', 'Londrina', 5555, 1326.00],
        ['São Paulo', 'São Carlos', 33333, 1508.00],
        ['Santa Catarina', 'Florianópolis', 99999, 1798.00],
        ['Paraná', 'Curitiba', 1111, 2222.00],
        ['São Paulo', 'Campinas', 1223237, 1710.00],
    ],
    columns=['Estado', 'Cidade', 'Habitantes', 'Salário-Médio'])
cidades
# Out:
#            Estado         Cidade  Habitantes  Salário-Médio
# 0          Paraná       Londrina        5555         1326.0
# 1       São Paulo     São Carlos       33333         1508.0
# 2  Santa Catarina  Florianópolis       99999         1798.0
# 3          Paraná       Curitiba        1111         2222.0
# 4       São Paulo       Campinas     1223237         1710.0
